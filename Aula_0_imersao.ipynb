# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaue557/Analise-de-Dados/blob/main/Aula_0_imersao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Aula 0");
# Out:
# kue
